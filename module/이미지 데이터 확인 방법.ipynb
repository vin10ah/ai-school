# %%
import os
import numpy as np
from glob import glob # 경로 반환
import matplotlib.pyplot as plt

import torch
from tensorflow import keras

# %%
data_dir = "/kaggle/input/a-module-1/chest_xray"

train_dir = os.path.join(data_dir, "train")
test_dir = os.path.join(data_dir, "test")

len(glob(f"{train_dir}/*/*")), len(glob(f"{test_dir}/*/*"))
# Out:
# (5216, 640)

# %%
glob(f"{train_dir}/*/*")[-16:]
# Out:
# ['/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0435-0001-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/NORMAL2-IM-1197-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0440-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/NORMAL2-IM-0885-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0516-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0523-0001-0003.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0205-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0552-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0277-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/NORMAL2-IM-0522-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0354-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/NORMAL2-IM-1160-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/NORMAL2-IM-0389-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0162-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/NORMAL2-IM-1247-0001.jpeg',
#  '/kaggle/input/a-module-1/chest_xray/train/NORMAL/IM-0219-0001.jpeg']

# %%
plt.imshow(plt.imread(glob(f"{train_dir}/*/*")[0]))

# %%
import random

plt.figure(figsize=(12, 12))
for i in range(16):
    path = random.choice(glob(f"{train_dir}/*/*"))
    img = plt.imread(path)
    plt.subplot(4, 4, i + 1)
    plt.title(path.split("/")[-2])
    plt.imshow(img, cmap="gray")
    plt.axis("off")
plt.show()

# %% [markdown]
# # 이미지 파일 읽어오는 법
#
# ## Torch
# jpeg 이미지는 `torch.tensor`로 변환되어야 합니다.

# %% [markdown]
# ### 옵션 1. torchvision.image -> torch.tensor

# %%
import torchvision

torchvision_image = torchvision.io.read_image(glob(f"{train_dir}/*/*")[0])

print(type(torchvision_image), torchvision_image.shape)
# Out:
# <class 'torch.Tensor'> torch.Size([1, 712, 1024])

# %% [markdown]
# ### 옵션 2. numpy array -> torch.tensor

# %%
import cv2

cv2_image = cv2.imread(glob(f"{train_dir}/*/*")[0])

print(type(cv2_image), cv2_image.shape)
# Out:
# <class 'numpy.ndarray'> (712, 1024, 3)

# %%
cv2_image = torch.from_numpy(cv2_image)
# 또는
# cv2_image = torch.tensor(cv2_image)

print(type(cv2_image), cv2_image.shape) # shape을 CHW로 변경 필요
# Out:
# <class 'torch.Tensor'> torch.Size([712, 1024, 3])

# %% [markdown]
# ### 옵션 3. torchvision으로 PIL, np ndarray -> torch.tensor 변환
#
# `torchvision.transforms.ToTensor()`를 사용

# %%
from PIL import Image

pil_image = Image.open(glob(f"{train_dir}/*/*")[0]).convert("RGB")

print(type(pil_image), pil_image.size)
# Out:
# <class 'PIL.Image.Image'> (1024, 712)

# %%
cv2_image = cv2.imread(glob(f"{train_dir}/*/*")[0])

print(type(cv2_image), cv2_image.shape)
# Out:
# <class 'numpy.ndarray'> (712, 1024, 3)

# %%
totensor = torchvision.transforms.ToTensor()

pil_image = totensor(pil_image)

print(type(pil_image), pil_image.shape)
# Out:
# <class 'torch.Tensor'> torch.Size([3, 712, 1024])

# %%
cv2_image = totensor(cv2_image)

print(type(cv2_image), cv2_image.shape)
# Out:
# <class 'torch.Tensor'> torch.Size([3, 712, 1024])

# %% [markdown]
# ## Keras
# Keras는 `numpy array`, `tf.Tensor`로 변환되어야 합니다.
#
# ### 옵션 1. `load_img`, `img_to_array` 사용

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

keras_img = img_to_array(load_img(glob(f"{train_dir}/*/*")[0]))

print(type(keras_img), keras_img.shape)
# Out:
# <class 'numpy.ndarray'> (712, 1024, 3)

# %% [markdown]
# ### 옵션 2. numpy array -> tf.Tensor

# %%
tf_image = tf.convert_to_tensor(keras_img)

print(type(tf_image), tf_image.shape)
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'> (712, 1024, 3)

# %% [markdown]
# ### 옵션 3. `tf.io.decode_image()`

# %%
import tensorflow as tf

tf_image = tf.io.decode_image(tf.io.read_file(glob(f"{train_dir}/*/*")[0]))

print(type(tf_image), tf_image.shape)
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'> (712, 1024, 1)
