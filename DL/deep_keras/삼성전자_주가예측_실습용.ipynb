# %% [markdown]
# #### 모듈 Import 데이터 불러오기

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, GRU

raw_df = pd.read_csv('005930.KS.csv')

# %%
raw_df.shape
# Out:
# (6172, 7)

# %% [markdown]
# #### yahoo finance 에서 데이터 다운로드 후 3일(3MA), 5일(5MA) 가격이동평균선 추가

# %%
raw_df['3MA'] = raw_df['Adj Close'].rolling(window=3).mean()
raw_df['5MA'] = raw_df['Adj Close'].rolling(window=5).mean()
raw_df.head()
# Out:
#          Date    Open    High     Low   Close    Adj Close    Volume  \
# 0  2000-01-04  6000.0  6110.0  5660.0  6110.0  4429.950684  74195000
# 1  2000-01-05  5800.0  6060.0  5520.0  5580.0  4045.683838  74680000
# 2  2000-01-06  5750.0  5780.0  5580.0  5620.0  4074.685059  54390000
# 3  2000-01-07  5560.0  5670.0  5360.0  5540.0  4016.685059  40305000
# 4  2000-01-10  5600.0  5770.0  5580.0  5770.0  4183.440430  46880000
#
#            3MA          5MA
# 0          NaN          NaN
# 1          NaN          NaN
# 2  4183.439860          NaN
# 3  4045.684652          NaN
# 4  4091.603516  4150.089014

# %%
plt.title('SAMSUNG ELECTRONICS STOCK PRICE')
plt.ylabel('PRICE')
plt.xlabel('PERIOD')

plt.plot(raw_df['Adj Close'], label='Adj Close')
plt.grid()

# %% [markdown]
# #### 데이터 전처리 (Missing Data 처리, 정규화 등)

# %%
# 통계정보 확인

raw_df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   6172.000000   6172.000000   6172.000000   6172.000000   6172.000000
# mean   28757.817563  29035.654569  28467.208360  28746.882696  24810.522704
# std    22959.695704  23139.691270  22758.678867  22936.538437  22396.824150
# min     2540.000000   2760.000000   2420.000000   2730.000000   1979.339600
# 25%    10775.000000  10940.000000  10635.000000  10780.000000   7900.805419
# 50%    21640.000000  21790.000000  21320.000000  21600.000000  16719.937500
# 75%    46042.500000  46410.000000  45570.000000  46005.000000  39203.531250
# max    90300.000000  96800.000000  89500.000000  91000.000000  87800.000000
#
#              Volume           3MA           5MA
# count  6.172000e+03   6170.000000   6168.000000
# mean   2.117354e+07  24805.171950  24800.123467
# std    1.502833e+07  22385.657588  22375.710644
# min    0.000000e+00   2022.841919   2037.342529
# 25%    1.171541e+07   7916.969930   7910.297559
# 50%    1.716862e+07  16779.096029  16701.423047
# 75%    2.614861e+07  39185.833333  39223.596094
# max    1.642150e+08  87733.333333  87540.000000

# %%
# Missing Data 확인

raw_df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# 3MA          2
# 5MA          4
# dtype: int64

# %%
for col in raw_df.columns:
	if raw_df[col].min() == 0:
		col_name = col
		print(col_name, type(col_name))
# Out:
# Volume <class 'str'>

# %%
# 최소값이 0 인 column 체크

raw_df.loc[raw_df['Volume']==0]
# Out:
#             Date     Open     High      Low    Close     Adj Close  Volume  \
# 23    2000-02-04   5130.0   5130.0   5130.0   5130.0   3719.420166       0
# 41    2000-03-01   5120.0   5120.0   5120.0   5120.0   3712.169434       0
# 66    2000-04-05   6800.0   6800.0   6800.0   6800.0   4930.226074       0
# 72    2000-04-13   6910.0   6910.0   6910.0   6910.0   5009.978027       0
# 84    2000-05-01   6000.0   6000.0   6000.0   6000.0   4350.199707       0
# ...          ...      ...      ...      ...      ...           ...     ...
# 5564  2022-02-28  71900.0  71900.0  71900.0  71900.0  68119.820313       0
# 5567  2022-03-04  72900.0  72900.0  72900.0  72900.0  69067.257813       0
# 5570  2022-03-10  69500.0  69500.0  69500.0  69500.0  65846.007813       0
# 5573  2022-03-15  70200.0  70200.0  70200.0  70200.0  66509.203125       0
# 5575  2022-03-17  70400.0  70400.0  70400.0  70400.0  66698.687500       0
#
#                3MA           5MA
# 23     3748.421631   3829.625000
# 41     3634.832520   3658.516846
# 66     5002.729004   4995.478418
# 72     5055.896972   5136.133984
# 84     4205.192220   4152.989502
# ...            ...           ...
# 5564  67993.497396  68953.560938
# 5567  68688.283855  68460.898438
# 5570  66035.494792  67248.200000
# 5573  66446.041667  66206.028125
# 5575  66635.526042  66547.100000
#
# [127 rows x 9 columns]

# %%
# 각 column에 0 몇개인지 확인

for col in raw_df.columns:
	missing_rows = raw_df.loc[raw_df[col]==0].shape[0]
	print(f'{col} : {missing_rows}')
# Out:
# Date : 0
# Open : 0
# High : 0
# Low : 0
# Close : 0
# Adj Close : 0
# Volume : 127
# 3MA : 0
# 5MA : 0

# %%
# 먼저 0 을 NaN 으로 바꾼후, Missing Data 처리
raw_df['Volume'] = raw_df['Volume'].replace(0, np.nan)


# 각 column에 0 몇개인지 확인
for col in raw_df.columns:
	missing_rows = raw_df.loc[raw_df[col]==0].shape[0]
	print(f'{col} : {missing_rows}')
# Out:
# Date : 0
# Open : 0
# High : 0
# Low : 0
# Close : 0
# Adj Close : 0
# Volume : 0
# 3MA : 0
# 5MA : 0

# %%
# missing data 확인

raw_df.isnull().sum()
# Out:
# Date           0
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume       127
# 3MA            2
# 5MA            4
# dtype: int64

# %%
raw_df.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume        True
# 3MA           True
# 5MA           True
# dtype: bool

# %%
raw_df.loc[raw_df['Volume'].isna()]
# Out:
#             Date     Open     High      Low    Close     Adj Close  Volume  \
# 23    2000-02-04   5130.0   5130.0   5130.0   5130.0   3719.420166     NaN
# 41    2000-03-01   5120.0   5120.0   5120.0   5120.0   3712.169434     NaN
# 66    2000-04-05   6800.0   6800.0   6800.0   6800.0   4930.226074     NaN
# 72    2000-04-13   6910.0   6910.0   6910.0   6910.0   5009.978027     NaN
# 84    2000-05-01   6000.0   6000.0   6000.0   6000.0   4350.199707     NaN
# ...          ...      ...      ...      ...      ...           ...     ...
# 5564  2022-02-28  71900.0  71900.0  71900.0  71900.0  68119.820313     NaN
# 5567  2022-03-04  72900.0  72900.0  72900.0  72900.0  69067.257813     NaN
# 5570  2022-03-10  69500.0  69500.0  69500.0  69500.0  65846.007813     NaN
# 5573  2022-03-15  70200.0  70200.0  70200.0  70200.0  66509.203125     NaN
# 5575  2022-03-17  70400.0  70400.0  70400.0  70400.0  66698.687500     NaN
#
#                3MA           5MA
# 23     3748.421631   3829.625000
# 41     3634.832520   3658.516846
# 66     5002.729004   4995.478418
# 72     5055.896972   5136.133984
# 84     4205.192220   4152.989502
# ...            ...           ...
# 5564  67993.497396  68953.560938
# 5567  68688.283855  68460.898438
# 5570  66035.494792  67248.200000
# 5573  66446.041667  66206.028125
# 5575  66635.526042  66547.100000
#
# [127 rows x 9 columns]

# %%
# missing data 처리

raw_df = raw_df.dropna()
raw_df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# 3MA          0
# 5MA          0
# dtype: int64

# %%
# 정규화 (Date 제외한 모든 수치부분 정규화)

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scale_cols = raw_df.columns[1:]

scaled_df = scaler.fit_transform(raw_df[scale_cols])
scaled_df = pd.DataFrame(scaled_df, columns=scale_cols)

scaled_df
# Out:
#           Open      High       Low     Close  Adj Close    Volume       3MA  \
# 0     0.034868  0.032008  0.036288  0.034440   0.025683  0.285359  0.024137
# 1     0.037375  0.035517  0.038470  0.034440   0.025683  0.363715  0.024560
# 2     0.034982  0.031689  0.036518  0.033873   0.025260  0.177799  0.025067
# 3     0.034868  0.031689  0.036059  0.033760   0.025176  0.250704  0.024898
# 4     0.036235  0.033177  0.037437  0.035120   0.026190  0.300555  0.025067
# ...        ...       ...       ...       ...        ...       ...       ...
# 6036  0.833637  0.776691  0.824299  0.815339   0.847356  0.099646  0.842882
# 6037  0.827940  0.777754  0.831190  0.824402   0.856678  0.059759  0.845993
# 6038  0.842753  0.785198  0.839228  0.831200   0.863669  0.065100  0.856494
# 6039  0.853008  0.797958  0.856454  0.843661   0.876487  0.080509  0.866216
# 6040  0.875798  0.816036  0.875976  0.862921   0.896295  0.053654  0.879439
#
#            5MA
# 0     0.024544
# 1     0.023968
# 2     0.024205
# 3     0.024358
# 4     0.024850
# ...        ...
# 6036  0.833895
# 6037  0.843487
# 6038  0.851909
# 6039  0.857758
# 6040  0.870625
#
# [6041 rows x 8 columns]

# %% [markdown]
# #### 주가예측을 위해 3MA, 5MA, Adj Close 항목을 feature 선정
#
# * 정답은 Adj Close 선정
# * 시계열 데이터를 위한 window_size = 40 선정

# %%
# 입력 파라미터 feature, label => numpy type

def make_sequene_dataset(feature, label, window_size):

	feature_list = []      # 생성될 feature list
	label_list = []        # 생성될 label list

	for i in range(len(feature)-window_size):
		feature_list.append(feature[i:i+window_size])
		label_list.append(label[i+window_size])

	return np.array(feature_list), np.array(label_list)

# %%
# feature_df, label_df 생성

feature_col = ['3MA', '5MA', 'Adj Close']
label_col = ['Adj Close']

feature_df = pd.DataFrame(scaled_df, columns=feature_col)
label_df = pd.DataFrame(scaled_df, columns=label_col)

# %%
# DataFrame => Numpy 변환

feature_np = feature_df.to_numpy()
label_np = label_df.to_numpy()

print(feature_np.shape, label_np.shape)
# Out:
# (6041, 3) (6041, 1)

# %%
feature_np
# Out:
# array([[0.02413662, 0.02454429, 0.02568264],
#        [0.02455958, 0.02396757, 0.02568264],
#        [0.02506712, 0.02420505, 0.02526023],
#        ...,
#        [0.85649365, 0.85190931, 0.86366919],
#        [0.8662163 , 0.85775807, 0.87648662],
#        [0.87943911, 0.87062535, 0.89629537]])

# %% [markdown]
# #### 시계열 데이터 생성 (make_sequence_dataset)

# %%
window_size = 40

X, Y = make_sequene_dataset(feature_np, label_np, window_size)

print(X.shape, Y.shape)
# Out:
# (6001, 40, 3) (6001, 1)

# %%
X
# Out:
# array([[[0.02413662, 0.02454429, 0.02568264],
#         [0.02455958, 0.02396757, 0.02568264],
#         [0.02506712, 0.02420505, 0.02526023],
#         ...,
#         [0.02433399, 0.02166072, 0.02762575],
#         [0.02580024, 0.02308554, 0.02458437],
#         [0.02506712, 0.02393365, 0.0244154 ]],
#
#        [[0.02455958, 0.02396757, 0.02568264],
#         [0.02506712, 0.02420505, 0.02526023],
#         [0.02489793, 0.02435771, 0.02517574],
#         ...,
#         [0.02580024, 0.02308554, 0.02458437],
#         [0.02506712, 0.02393365, 0.0244154 ],
#         [0.02484154, 0.02529062, 0.02694988]],
#
#        [[0.02506712, 0.02420505, 0.02526023],
#         [0.02489793, 0.02435771, 0.02517574],
#         [0.02506712, 0.02484961, 0.02618954],
#         ...,
#         [0.02506712, 0.02393365, 0.0244154 ],
#         [0.02484154, 0.02529062, 0.02694988],
#         [0.02478514, 0.02484961, 0.0244154 ]],
#
#        ...,
#
#        [[0.89594978, 0.89040987, 0.90265347],
#         [0.90214466, 0.90135673, 0.91889418],
#         [0.91569591, 0.90834408, 0.92353431],
#         ...,
#         [0.834326  , 0.8453587 , 0.83220824],
#         [0.84288193, 0.83389512, 0.8473561 ],
#         [0.84599318, 0.84348709, 0.85667787]],
#
#        [[0.90214466, 0.90135673, 0.91889418],
#         [0.91569591, 0.90834408, 0.92353431],
#         [0.91647029, 0.90927574, 0.90497362],
#         ...,
#         [0.84288193, 0.83389512, 0.8473561 ],
#         [0.84599318, 0.84348709, 0.85667787],
#         [0.85649365, 0.85190931, 0.86366919]],
#
#        [[0.91569591, 0.90834408, 0.92353431],
#         [0.91647029, 0.90927574, 0.90497362],
#         [0.91414722, 0.91509853, 0.9119339 ],
#         ...,
#         [0.84599318, 0.84348709, 0.85667787],
#         [0.85649365, 0.85190931, 0.86366919],
#         [0.8662163 , 0.85775807, 0.87648662]]])

# %%
# train, test 분리

#split = int(len(X)*0.95)
split = -200

x_train = X[0:split]
y_train = Y[0:split]

x_test = X[split:]
y_test = Y[split:]

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (5801, 40, 3) (5801, 1)
# (200, 40, 3) (200, 1)

# %% [markdown]
# #### 모델 구축 및 컴파일

# %%
# model 생성

model = Sequential()
model.add(LSTM(128, activation='tanh', input_shape=x_train[0].shape))
model.add(Dense(64, activation='tanh'))
model.add(Dense(1, activation='linear'))
# Out:
# /Users/vin_ah/miniconda3/envs/new_env/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 128)            │        67,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,905 (296.50 KB)
#  Trainable params: 75,905 (296.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 모델 학습 (EarlyStopping 적용)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=5)

model.fit(x_train, y_train,
		epochs=100,
		batch_size=16,
		callbacks=early_stop,
		validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0059 - mae: 0.0291 - val_loss: 7.4365e-04 - val_mae: 0.0203
# Epoch 2/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.2024e-04 - mae: 0.0070 - val_loss: 7.5884e-04 - val_mae: 0.0207
# Epoch 3/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.1241e-04 - mae: 0.0067 - val_loss: 6.1010e-04 - val_mae: 0.0181
# Epoch 4/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.0746e-04 - mae: 0.0068 - val_loss: 5.6125e-04 - val_mae: 0.0173
# Epoch 5/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.0908e-04 - mae: 0.0068 - val_loss: 7.5281e-04 - val_mae: 0.0218
# Epoch 6/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 9.6015e-05 - mae: 0.0064 - val_loss: 4.7423e-04 - val_mae: 0.0159
# Epoch 7/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.0768e-04 - mae: 0.0069 - val_loss: 4.8159e-04 - val_mae: 0.0163
# Epoch 8/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 8.6724e-05 - mae: 0.0063 - val_loss: 4.7485e-04 - val_mae: 0.0164
# Epoch 9/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 8.2224e-05 - mae: 0.0062 - val_loss: 4.6586e-04 - val_mae: 0.0162
# Epoch 10/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 9.5565e-05 - mae: 0.0065 - val_loss: 3.4245e-04 - val_mae: 0.0131
# Epoch 11/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 6.8218e-05 - mae: 0.0055 - val_loss: 3.2181e-04 - val_mae: 0.0127
# Epoch 12/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 6.7134e-05 - mae: 0.0055 - val_loss: 4.5314e-04 - val_mae: 0.0167
# Epoch 13/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 6.6551e-05 - mae: 0.0055 - val_loss: 3.0487e-04 - val_mae: 0.0123
# Epoch 14/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 5.6182e-05 - mae: 0.0050 - val_loss: 2.8524e-04 - val_mae: 0.0121
# Epoch 15/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 5.3861e-05 - mae: 0.0050 - val_loss: 2.7491e-04 - val_mae: 0.0119
# Epoch 16/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 7.0449e-05 - mae: 0.0057 - val_loss: 2.8583e-04 - val_mae: 0.0125
# Epoch 17/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 5.6525e-05 - mae: 0.0052 - val_loss: 4.0385e-04 - val_mae: 0.0157
# Epoch 18/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 5.2916e-05 - mae: 0.0049 - val_loss: 8.1570e-04 - val_mae: 0.0246
# Epoch 19/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 4.6650e-05 - mae: 0.0046 - val_loss: 2.7296e-04 - val_mae: 0.0120
# Epoch 20/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 5.4280e-05 - mae: 0.0050 - val_loss: 2.4945e-04 - val_mae: 0.0114
# Epoch 21/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 4.9828e-05 - mae: 0.0047 - val_loss: 3.5534e-04 - val_mae: 0.0147
# Epoch 22/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 4.7203e-05 - mae: 0.0047 - val_loss: 4.4240e-04 - val_mae: 0.0171
# Epoch 23/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 6.1800e-05 - mae: 0.0054 - val_loss: 8.0142e-04 - val_mae: 0.0247
# Epoch 24/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 4.6279e-05 - mae: 0.0046 - val_loss: 6.4311e-04 - val_mae: 0.0216
# Epoch 25/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 6.3886e-05 - mae: 0.0056 - val_loss: 2.8032e-04 - val_mae: 0.0125

# %% [markdown]
# #### 예측을 통한 정답과의 비교 (오차계산 MAPE 사용, 평균절대값백분율오차)

# %%
pred = model.predict(x_test)

plt.figure(figsize=(12, 6))
plt.title('3MA + 5MA + Adj Close, window_size=40')
plt.ylabel('adj close')
plt.xlabel('period')
plt.plot(y_test, label='actual')
plt.plot(pred, label='prediction')
plt.grid()
plt.legend(loc='best')

plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# 평균절대값백분율오차계산 (MAPE)

print(np.sum(abs(y_test-pred)/y_test) / len(x_test) * 100)
# Out:
# 1.4331642357425831

# %%
# model 생성

model = Sequential()
model.add(LSTM(64, activation='tanh', return_sequences=True, input_shape=x_train[0].shape))
model.add(LSTM(64, activation='tanh', return_sequences=True))
model.add(LSTM(64, activation='tanh', return_sequences=True))
model.add(LSTM(32, activation='tanh'))
model.add(Dense(1, activation='linear'))

optimizer = tf.keras.optimizers.AdamW(learning_rate=0.001)
model.compile(loss='mse', optimizer=optimizer, metrics=['mae'])

model.summary()
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_23 (LSTM)                  │ (None, 40, 64)         │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_24 (LSTM)                  │ (None, 40, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_25 (LSTM)                  │ (None, 40, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_26 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,905 (374.63 KB)
#  Trainable params: 95,905 (374.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#### 모델 학습 (EarlyStopping 적용)

early_stop = EarlyStopping(monitor='val_loss', patience=5)

model.fit(x_train, y_train,
		epochs=100,
		batch_size=32,
		callbacks=early_stop,
		validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0099 - mae: 0.0482 - val_loss: 0.0032 - val_mae: 0.0437
# Epoch 2/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 4.1296e-04 - mae: 0.0123 - val_loss: 0.0025 - val_mae: 0.0371
# Epoch 3/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 3.4147e-04 - mae: 0.0116 - val_loss: 0.0016 - val_mae: 0.0306
# Epoch 4/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 3.5098e-04 - mae: 0.0118 - val_loss: 0.0022 - val_mae: 0.0381
# Epoch 5/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 2.8050e-04 - mae: 0.0107 - val_loss: 0.0024 - val_mae: 0.0401
# Epoch 6/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 2.7973e-04 - mae: 0.0109 - val_loss: 0.0018 - val_mae: 0.0342
# Epoch 7/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 2.1821e-04 - mae: 0.0095 - val_loss: 0.0011 - val_mae: 0.0264
# Epoch 8/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 2.2712e-04 - mae: 0.0098 - val_loss: 0.0012 - val_mae: 0.0267
# Epoch 9/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 2.4305e-04 - mae: 0.0101 - val_loss: 0.0014 - val_mae: 0.0307
# Epoch 10/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.9406e-04 - mae: 0.0092 - val_loss: 0.0012 - val_mae: 0.0286
# Epoch 11/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 2.1796e-04 - mae: 0.0097 - val_loss: 7.3097e-04 - val_mae: 0.0203
# Epoch 12/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.6676e-04 - mae: 0.0083 - val_loss: 0.0027 - val_mae: 0.0461
# Epoch 13/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 2.1722e-04 - mae: 0.0095 - val_loss: 8.2297e-04 - val_mae: 0.0226
# Epoch 14/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - loss: 1.5261e-04 - mae: 0.0081 - val_loss: 5.0131e-04 - val_mae: 0.0165
# Epoch 15/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.0388e-04 - mae: 0.0067 - val_loss: 4.6786e-04 - val_mae: 0.0157
# Epoch 16/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 49s 271ms/step - loss: 1.1528e-04 - mae: 0.0070 - val_loss: 5.0157e-04 - val_mae: 0.0168
# Epoch 17/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.0845e-04 - mae: 0.0070 - val_loss: 5.3172e-04 - val_mae: 0.0177
# Epoch 18/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.0758e-04 - mae: 0.0068 - val_loss: 3.4752e-04 - val_mae: 0.0134
# Epoch 19/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 67s 372ms/step - loss: 9.5336e-05 - mae: 0.0065 - val_loss: 0.0013 - val_mae: 0.0320
# Epoch 20/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.0780e-04 - mae: 0.0070 - val_loss: 3.0936e-04 - val_mae: 0.0129
# Epoch 21/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 220s 1s/step - loss: 7.8242e-05 - mae: 0.0060 - val_loss: 4.3221e-04 - val_mae: 0.0163
# Epoch 22/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 7.1950e-05 - mae: 0.0057 - val_loss: 0.0017 - val_mae: 0.0382
# Epoch 23/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 8.9394e-05 - mae: 0.0067 - val_loss: 2.5439e-04 - val_mae: 0.0116
# Epoch 24/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1014s 6s/step - loss: 8.5430e-05 - mae: 0.0061 - val_loss: 4.6111e-04 - val_mae: 0.0173
# Epoch 25/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 940s 5s/step - loss: 6.2436e-05 - mae: 0.0053 - val_loss: 3.4981e-04 - val_mae: 0.0146
# Epoch 26/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1004s 6s/step - loss: 6.4323e-05 - mae: 0.0054 - val_loss: 3.0504e-04 - val_mae: 0.0133
# Epoch 27/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1080s 6s/step - loss: 6.8204e-05 - mae: 0.0055 - val_loss: 3.4159e-04 - val_mae: 0.0144
# Epoch 28/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1080s 6s/step - loss: 6.1693e-05 - mae: 0.0053 - val_loss: 4.5003e-04 - val_mae: 0.0172

# %%
#### 예측을 통한 정답과의 비교 (오차계산 MAPE 사용, 평균절대값백분율오차)
pred = model.predict(x_test)

plt.figure(figsize=(12, 6))
plt.title('3MA + 5MA + Adj Close, window_size=40')
plt.ylabel('adj close')
plt.xlabel('period')
plt.plot(y_test, label='actual')
plt.plot(pred, label='prediction')
plt.grid()
plt.legend(loc='best')

plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
# 평균절대값백분율오차계산 (MAPE)

print(np.sum(abs(y_test-pred)/y_test) / len(x_test) * 100)
# Out:
# 2.006796519431613
